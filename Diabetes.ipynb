# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishu-5/Decision-tree/blob/main/Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
import graphviz

# %%
#library

#import dataset
#EDA
#x,y Variables
#PREPROCESSING
#train test split

#algorithms

#accuracy
#EDA
#graph visualization

# %%
df=pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.shape
# Out:
# (768, 9)

# %%
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False  False    False
# 2                       False  False    False
# 3                       False  False    False
# 4                       False  False    False
# ..                        ...    ...      ...
# 763                     False  False    False
# 764                     False  False    False
# 765                     False  False    False
# 766                     False  False    False
# 767                     False  False    False
#
# [768 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.notnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           True     True           True           True     True  True
# 1           True     True           True           True     True  True
# 2           True     True           True           True     True  True
# 3           True     True           True           True     True  True
# 4           True     True           True           True     True  True
# ..           ...      ...            ...            ...      ...   ...
# 763         True     True           True           True     True  True
# 764         True     True           True           True     True  True
# 765         True     True           True           True     True  True
# 766         True     True           True           True     True  True
# 767         True     True           True           True     True  True
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                        True  True     True
# 1                        True  True     True
# 2                        True  True     True
# 3                        True  True     True
# 4                        True  True     True
# ..                        ...   ...      ...
# 763                      True  True     True
# 764                      True  True     True
# 765                      True  True     True
# 766                      True  True     True
# 767                      True  True     True
#
# [768 rows x 9 columns]

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
x=df.Glucose
y=df.BloodPressure
plt.plot(x,y)
plt.xlabel("Glucose")
plt.ylabel("BloodPressure")
plt.title("Diabetes")
# Out:
# Text(0.5, 1.0, 'Diabetes')

# %%
plt.scatter(x,y)
plt.xlabel("Glucose")
plt.ylabel("BloodPressure")
plt.title("Diabetes")
# Out:
# Text(0.5, 1.0, 'Diabetes')

# %%
plt.bar(x,y)
plt.xlabel("Glucose")
plt.ylabel("BloodPressure")
plt.title("Diabetes")
# Out:
# Text(0.5, 1.0, 'Diabetes')

# %%
plt.hist(x)
plt.xlabel("Glucose")
plt.title("Diabetes")
# Out:
# Text(0.5, 1.0, 'Diabetes')

# %%
plt.barh(x,y)
plt.xlabel("Glucose")
plt.ylabel("BloodPressure")
plt.title("Diabetes")
# Out:
# Text(0.5, 1.0, 'Diabetes')

# %%
plt.pie(x)
plt.title("Diabetes")
# Out:
# Text(0.5, 1.0, 'Diabetes')

# %%
plt.polar(y)
plt.title("Diabetes")
# Out:
# Text(0.5, 1.05, 'Diabetes')

# %%
plt.stem(y)
plt.title("Diabetes")
# Out:
# <ipython-input-32-9ce5648da6f2>:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(y)
# Text(0.5, 1.0, 'Diabetes')

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7b99097640>,
#   <matplotlib.lines.Line2D at 0x7f7b990979a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f7b99097d00>,
#   <matplotlib.lines.Line2D at 0x7f7b990a20a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7b990972e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7b990a2400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7b990a2700>],
#  'means': []}

# %%
x=df.drop('Outcome',axis=1)# row removal axis=0, col removal axis=1
y=df['Outcome']

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for col in x.columns:
  if plotnumber <=8:
    ax=plt.subplot(5,5,plotnumber)
    sns.boxplot(x[col])
    plt.xlabel(col,fontsize=15)
  plotnumber+=1
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
import missingno as msno

msno.bar(df)
plt.show()

# %%
x_train,x_test,y_test,y_train=train_test_split(x,y,test_size = 0.2, random_state=0)

# %%
clf= DecisionTreeClassifier(criterion='entropy',random_state=0)
clf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-429416a4247e> in <module>
#       1 clf= DecisionTreeClassifier(criterion='entropy',random_state=0)
# ----> 2 clf.fit(x_train,y_train)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     297
#     298         if len(y) != n_samples:
# --> 299             raise ValueError(
#     300                 "Number of labels=%d does not match number of samples=%d"
#     301                 % (len(y), n_samples)
#
# ValueError: Number of labels=154 does not match number of samples=614

# %%
y_pred=clf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-e994088b5522> in <module>
# ----> 1 y_pred=clf.predict(x_test)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     466         check_is_fitted(self)
#     467         X = self._validate_X_predict(X, check_input)
# --> 468         proba = self.tree_.predict(X)
#     469         n_samples = X.shape[0]
#     470
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'tree_'

# %%
cm=confusion_matrix(y_test,y_pred)
cm

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)

# %%
accuracy=(cm[0][0] + cm[-1][-1])/np.sum(cm)
print(accuracy)

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for col in x.columns:
  if plotnumber <=8:
    ax=plt.subplot(5,5,plotnumber)
    sns.distplot(x[col])
    plt.xlabel(col,fontsize=15)
  plotnumber+=1
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for col in x.columns:
  if plotnumber <=8:
    ax=plt.subplot(5,5,plotnumber)
    plt.hist(x[col])
    plt.xlabel(col,fontsize=15)
  plotnumber+=1
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for col in x.columns:
  if plotnumber <=8:
    ax=plt.subplot(5,5,plotnumber)
    plt.pie(x[col])
    plt.xlabel(col,fontsize=15)
  plotnumber+=1
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for col in x.columns:
  if plotnumber <=8:
    ax=plt.subplot(5,5,plotnumber)
    plt.stem(x[col])
    plt.xlabel(col,fontsize=15)
  plotnumber+=1
plt.tight_layout()
plt.show()
